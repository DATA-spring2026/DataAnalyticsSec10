# %% [markdown]
# # Review - Wk 5, Ex 3.A, Lab 1
# ## Numeric conversion (conversion_tests.py)

# %%
a = " 101.1 " 
b = '55' 
c = "402 Stevens" 
d = 'Number 5 '

# %%
# print(int(a))  # can't cast directly as a string, TypeError
print(float(a))
# print(float(int(a)))
print(int(float(a)))
# Out:
# 101.1
# 101

# %% [markdown]
# Use slicing to add just the numeric portion of the string to a new variable (remember, indexing always starts with 0!), and cast the number as an integer or string, whichever is appropriate

# %%
# slice a to just get 101.1

x = float(a[1:-1])

x
# Out:
# 101.1

# %%
y = int(c[:3])

y
# Out:
# 402

# %% [markdown]
# # Quick Jupyter Notebook Example
#
# ## Bonus example
#
# Here is what a markdown block looks like in Juptyer Notebook.

# %%
first_name = input("What is your first name? ")
last_name = input("What is your last name? ")
zip = int(input("What is your 5-digit zip code? "))
# Out:
# What is your first name?  Theodore
# What is your last name?  Roosevelt
# What is your 5-digit zip code?  01234

# %%
print(first_name, last_name)
print("Zip code:", zip)
# Out:
# Theodore Roosevelt
# Zip code: 1234
